# %% [markdown]
# # Importamos las librerías a utilizar

# %%
#Para crear y análizar redes
import networkx as nx
#Para dibujary guardas gráficas de redes y funciones
import matplotlib.pyplot as plt

# %% [markdown]
# # Creación de la red

# %% [markdown]
# **ACTIVIDAD 1** Complete la siguiente lista de enlaces para representar la red de amistades de la Práctica 1.
# Python distingue entre mayúsculas y minúsculas.

# %%
lista_enlaces = [
    ("Alicia","Beto"),
    ("Carlos","Alicia"),("Alicia","David"),("Alicia","Carmen"),("Alicia","Monica"),("Beto","Jorge"),
    ("Jorge","Enrique"),("Enrique","Rosa"),("Rosa","Jorge"),("Enrique","Irene"),("Irene","Jorge"),
    ("Irene","Rosa"),("Carmen","Monica"),("David","Carlos"),("Carlos","Monica"),("Carmen","Irene")
                ]

# %% [markdown]
# Creamos la red y la almacenamos en la variable G

# %%
G = nx.Graph(lista_enlaces)

# %% [markdown]
# ## Dibujamos y guardamos la red

# %% [markdown]
# Dibujamos la red con nodos rosas y mostrando las etiquetas de los nodos. Depués, guardamos la red en el archivo amigos.png

# %%
nx.draw(G,with_labels=True,node_color="pink")
plt.savefig("amigos.png")

# %% [markdown]
# **ACTIVIDAD 2** Dibuje la red con nodos azules y sin mostrar las etiquetas de nodos

# %%
nx.draw(G,with_labels=False,node_color="blue")

# %% [markdown]
# **ACTIVIDAD 3** Dibuje la red con nodos verdes y mostrando las etiquetas de nodos

# %%
nx.draw(G,with_labels=True,node_color="green")

# %% [markdown]
# # Nodos y enlaces

# %% [markdown]
# ## Nodos

# %% [markdown]
# Guardamos la lista de nodos en la variable nodos y la MOSTRAMOS

# %%
nodos = nx.nodes(G)
nodos
# Out:
# NodeView(('Alicia', 'Beto', 'Carlos', 'David', 'Carmen', 'Monica', 'Jorge', 'Enrique', 'Rosa', 'Irene'))

# %% [markdown]
# Guardamos el tamaño de la lista de enlaces en la variable n y la MOSTRAMOS

# %%
n = len(nodos)
n
# Out:
# 10

# %% [markdown]
# ## Enlaces

# %% [markdown]
# **ACTIVIDAD 4** Guarde la lista de enlaces en una variable enlaces y muestrela

# %%
enlaces=nx.edges(G)
enlaces
# Out:
# EdgeView([('Alicia', 'Beto'), ('Alicia', 'Carlos'), ('Alicia', 'David'), ('Alicia', 'Carmen'), ('Alicia', 'Monica'), ('Beto', 'Jorge'), ('Carlos', 'David'), ('Carlos', 'Monica'), ('Carmen', 'Monica'), ('Carmen', 'Irene'), ('Jorge', 'Enrique'), ('Jorge', 'Rosa'), ('Jorge', 'Irene'), ('Enrique', 'Rosa'), ('Enrique', 'Irene'), ('Rosa', 'Irene')])

# %% [markdown]
# **ACTIVIDAD 5** Guarde el tamaño de la lista de enlaces en una variable m y muestrela

# %%
m=len(enlaces)
m
# Out:
# 16

# %% [markdown]
# # Distancias y caminos

# %% [markdown]
# ## Distancia y camino entre 2 personas
# La distancia entre 2 nodos es el la longitud del camino más corto
# ### Beto y Carlos
# Calculamos uno de los caminos mas cortos entre Carlos e Irene y lo IMPRIMOS

# %%
camino = nx.shortest_path(G,"Beto","Carlos")
print("El camino más corto entre Beto y Carlos " + str(camino))
# Out:
# El camino más corto entre Beto y Carlos ['Beto', 'Alicia', 'Carlos']

# %% [markdown]
# Calculamos la distancia entre Beto y Carlos y la IMPRIMOS

# %%
distancia = nx.shortest_path_length(G,"Beto","Carlos")
print("La distancia entre Beto y Carlos es " + str(distancia))
# Out:
# La distancia entre Beto y Carlos es 2

# %% [markdown]
# Calculamos TODOS los caminos mas cortos entre Carlos y Beto, los guardamos en la variable caminos

# %%
caminos = nx.all_shortest_paths(G,"Carlos","Beto")

# %% [markdown]
# Con ayuda de un ciclo for imprimos todos los caminos entre Carlos y Beto

# %%
for camino in caminos: 
    print("El camino más corto entre Carlos y Beto " + str(camino))
# Out:
# El camino más corto entre Carlos y Beto ['Carlos', 'Alicia', 'Beto']

# %% [markdown]
# ### Carlos e Irene

# %% [markdown]
# **ACTIVIDAD 6** Repita los calculos realizados para Carlos y Beto, pero ahora para Carlos e Irene

# %%
# Calculamos uno de los caminos mas cortos entre Carlos e Irene y lo mostramos en la consola
caminoCI = nx.shortest_path(G,"Carlos","Irene")
print("El camino más corto entre Carlos e Irene " + str(caminoCI))
# Out:
# El camino más corto entre Carlos e Irene ['Carlos', 'Alicia', 'Carmen', 'Irene']

# %%
#Calculamos la distancia entre Carlos e Irene y la IMPRIMOS
distanciaCI = nx.shortest_path_length(G,"Carlos","Irene")
print("La distancia entre Carlos e Irene es " + str(distanciaCI))
# Out:
# La distancia entre Carlos e Irene es 3

# %%
#Calculamos TODOS los caminos mas cortos entre Carlos e Irene, los guardamos en la variable caminos
caminosCI = nx.all_shortest_paths(G,"Carlos","Irene")

#Con ayuda de un ciclo for imprimos todos los caminos entre Carlos e Irene

for caminoCI in caminosCI: 
    print("Los caminos más cortos entre Carlos e Irene " + str(caminoCI))
# Out:
# Los caminos más cortos entre Carlos e Irene ['Carlos', 'Alicia', 'Carmen', 'Irene']
# Los caminos más cortos entre Carlos e Irene ['Carlos', 'Monica', 'Carmen', 'Irene']

# %% [markdown]
# ### Carlos y Enrique

# %% [markdown]
# **ACTIVIDAD 7** Repita los calculos realizados para Carlos y Beto, pero ahora para Carlos e Enrique

# %%
# Calculamos uno de los caminos mas cortos entre Carlos y Enrique y lo mostramos en la consola
caminoCE = nx.shortest_path(G,"Carlos","Enrique")
print("El camino más corto entre Carlos y Enrique " + str(caminoCE))
# Out:
# El camino más corto entre Carlos y Enrique ['Carlos', 'Alicia', 'Beto', 'Jorge', 'Enrique']

# %%
#Calculamos la distancia entre Carlos y Enrique y la IMPRIMOS
distanciaCE = nx.shortest_path_length(G,"Carlos","Enrique")
print("La distancia entre Carlos y Enrique es " + str(distanciaCE))
# Out:
# La distancia entre Carlos y Enrique es 4

# %%
#Calculamos TODOS los caminos mas cortos entre Carlos y Enrique, los guardamos en la variable caminosCE
caminosCE = nx.all_shortest_paths(G,"Carlos","Enrique")

#Con ayuda de un ciclo for imprimos todos los caminos entre Carlos y Enrique

for caminoCE in caminosCE: 
    print("Los caminos más cortos entre Carlos Y Enrique " + str(caminoCE))
# Out:
# Los caminos más cortos entre Carlos Y Enrique ['Carlos', 'Alicia', 'Beto', 'Jorge', 'Enrique']
# Los caminos más cortos entre Carlos Y Enrique ['Carlos', 'Alicia', 'Carmen', 'Irene', 'Enrique']
# Los caminos más cortos entre Carlos Y Enrique ['Carlos', 'Monica', 'Carmen', 'Irene', 'Enrique']

# %% [markdown]
# ## Funcion para mostrar los caminos (más cortos) y distancia

# %% [markdown]
# La siguiente funcion recibe como parametros los nodos: nodo1 y nodo2 e imprime los caminos mas cortos entre ellos. La funcion devuelve la distancia entre el nodo1 y el nodo2

# %%
def cam_dist(nodo1,nodo2):
    """
    Recibe como parametros los nodos: nodo1 y nodo2
    Imprime los caminos mas cortos entre nodo1 y nodo2 
    Devuelve la distancia entre el nodo1 y el nodo2
    """
    caminos = nx.all_shortest_paths(G, nodo1, nodo2)
    for camino in caminos: 
        print("Uno de los caminos más corto entre " + nodo1 + " y " + nodo2 +" es " + str(camino))
    distancia = nx.shortest_path_length(G, nodo1, nodo2)
    return distancia

# %% [markdown]
# Utilizamos las funciones para mostrar caminos y distancias

# %%
dist_BetoCarlos = cam_dist("Beto","Carlos")
dist_BetoCarlos
# Out:
# Uno de los caminos más corto entre Beto y Carlos es ['Beto', 'Alicia', 'Carlos']
# 2

# %% [markdown]
# ## Diámetro
# Distancia más larga entre dos nodos

# %%
diametro = nx.diameter(G)
print("El diámetero de la red es " + str(diametro))
# Out:
# El diámetero de la red es 4

# %% [markdown]
# ## Distancia promedio

# %%
prom_dist = nx.average_shortest_path_length(G)
print("La distancia promedio es " + str(prom_dist))
# Out:
# La distancia promedio es 2.022222222222222

# %% [markdown]
# ## Funcion para calcular la distancia promedio y diametro de una red

# %% [markdown]
# **ACTIVIDAD 7** Cree una funcion recibe como parametros una red G, que imprima el diámetro y la distancia promedio de G. La funcion debe devolver la distancia promedio de G

# %%
# La rutina diam_dist(Red) trabaja con un argumento (paso por valor). Manda a la salida estandar
#(pantalla) la media aritmetica de las distancias de la gráfica. También, imprime en la consola el 
# diámetro del grafo.
def diam_dist(Red):
   
    diametro = nx.diameter(Red)
    print("El diámetero de la red es " + str(diametro))
    prom_dist = nx.average_shortest_path_length(Red)
    print("La distancia promedio es " + str(prom_dist))
    
    return prom_dist

# %% [markdown]
# **ACTIVIDAD 8** Llame a la función de la actividad 7, para imprimir el diámetro y la distancia de la red creada

# %%
diam_dista=diam_dist(G)
# Out:
# El diámetero de la red es 4
# La distancia promedio es 2.022222222222222
